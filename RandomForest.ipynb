# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %%
SFNT = pd.read_csv('F:/flight_delay_new/SFSNT.csv')

# %%
SFNT.head(5)
# Out:
#    SSC    FLT   ORG   DES   STD   STA FLO  MON  TUE WED  THU FRI  SAT  SUN  \
# 0  S19  A1915  ARP1  ARP3  7:55  9:05   A    Y    Y   Y    Y   Y    Y    Y
# 1  S19  A1904  ARP3  ARP1  7:55  9:05   A    Y    Y   Y    Y   Y    Y    Y
# 2  S19  I1304  ARP3  ARP1  8:00  9:15   I    Y  NaN   Y    Y   Y  NaN    Y
# 3  S19  B1802  ARP2  ARP1  8:00  8:55   B    Y    Y   Y    Y   Y    Y    Y
# 4  S19  J1106  ARP1  ARP2  8:00  9:05   J  NaN    Y   Y  NaN   Y    Y  NaN
#
#         FSD       FED IRR
# 0  20190331  20191026   N
# 1  20190331  20191026   N
# 2  20190331  20191026   N
# 3  20190331  20191026   N
# 4  20190730  20190824   N

# %%
df =pd.read_csv("F:/flight_delay_new/AFSNT.csv",encoding = "ISO-8859-1")

# %%
df.head(5)
# Out:
#    SDT_YY  SDT_MM  SDT_DD SDT_DY   ARP   ODP FLO    FLT       REG AOD IRR  \
# 0    2017       1       1     ÀÏ  ARP3  ARP6   J  J1955  SEw3NzE4   D   N
# 1    2017       1       1     ÀÏ  ARP3  ARP6   J  J1954  SEw3NzE4   A   N
# 2    2017       1       1     ÀÏ  ARP3  ARP6   J  J1956  SEw3NzE4   A   N
# 3    2017       1       1     ÀÏ  ARP3  ARP6   J  J1957  SEw3NzE4   D   N
# 4    2017       1       1     ÀÏ  ARP3  ARP6   J  J1958  SEw3NzE4   A   N
#
#      STT    ATT DLY  DRR CNL  CNR
# 0  10:05  10:32   N  NaN   N  NaN
# 1   9:30   9:31   N  NaN   N  NaN
# 2  12:45  13:03   N  NaN   N  NaN
# 3  13:25  14:09   Y  C02   N  NaN
# 4  16:10  16:31   N  NaN   N  NaN

# %%
df.tail(5)
# Out:
#         SDT_YY  SDT_MM  SDT_DD SDT_DY   ARP   ODP FLO    FLT       REG AOD  \
# 987704    2019       6      30     ÀÏ  ARP3  ARP4   L  L1810  SEw4MjM1   D
# 987705    2019       6      30     ÀÏ  ARP3  ARP4   L  L1809  SEw4MjM1   A
# 987706    2019       6      30     ÀÏ  ARP3  ARP4   L  L1801  SEw4MzYz   A
# 987707    2019       6      30     ÀÏ  ARP3  ARP4   L  L1807  SEw4MjM3   A
# 987708    2019       6      30     ÀÏ  ARP3  ARP4   L  L1804  SEw4MjM3   D
#
#        IRR    STT    ATT DLY  DRR CNL  CNR
# 987704   N  21:10  21:53   Y  C02   N  NaN
# 987705   N  20:35  20:59   N  NaN   N  NaN
# 987706   N   7:20   7:10   N  NaN   N  NaN
# 987707   N  17:30  17:32   N  NaN   N  NaN
# 987708   N  14:45  14:54   N  NaN   N  NaN

# %%
df.shape
# Out:
# (987709, 17)

# %%
df['SDT_YY'].unique()
# Out:
# array([2017, 2018, 2019], dtype=int64)

# %%
df['DLY'].unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
df['AOD'].unique()
# Out:
# array(['D', 'A'], dtype=object)

# %%
df['ARP'].unique()
# Out:
# array(['ARP3', 'ARP2', 'ARP1', 'ARP4', 'ARP8', 'ARP14', 'ARP12', 'ARP6',
#        'ARP5', 'ARP9', 'ARP13', 'ARP11', 'ARP15', 'ARP7', 'ARP10'],
#       dtype=object)

# %%
df['FLO'].unique()
# Out:
# array(['J', 'B', 'F', 'C', 'A', 'H', 'E', 'K', 'I', 'L', 'G', 'D'],
#       dtype=object)

# %%
df['ODP'].unique()
# Out:
# array(['ARP6', 'ARP3', 'ARP1', 'ARP12', 'ARP15', 'ARP11', 'ARP13', 'ARP8',
#        'ARP2', 'ARP9', 'ARP4', 'ARP5', 'ARP14', 'ARP7', 'ARP10'],
#       dtype=object)

# %%
df['SDT_DY'].unique()
# Out:
# array(['ÀÏ', '¿ù', 'È\xad', '¼ö', '¸ñ', '±Ý', 'Åä'], dtype=object)

# %%
df.columns
# Out:
# Index(['SDT_YY', 'SDT_MM', 'SDT_DD', 'SDT_DY', 'ARP', 'ODP', 'FLO', 'FLT',
#        'REG', 'AOD', 'IRR', 'STT', 'ATT', 'DLY', 'DRR', 'CNL', 'CNR'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
df.head(5)
# Out:
#    SDT_YY  SDT_MM  SDT_DD SDT_DY   ARP   ODP FLO    FLT       REG AOD IRR  \
# 0    2017       1       1     ÀÏ  ARP3  ARP6   J  J1955  SEw3NzE4   D   N
# 1    2017       1       1     ÀÏ  ARP3  ARP6   J  J1954  SEw3NzE4   A   N
# 2    2017       1       1     ÀÏ  ARP3  ARP6   J  J1956  SEw3NzE4   A   N
# 3    2017       1       1     ÀÏ  ARP3  ARP6   J  J1957  SEw3NzE4   D   N
# 4    2017       1       1     ÀÏ  ARP3  ARP6   J  J1958  SEw3NzE4   A   N
#
#      STT    ATT DLY  DRR CNL  CNR
# 0  10:05  10:32   N  NaN   N  NaN
# 1   9:30   9:31   N  NaN   N  NaN
# 2  12:45  13:03   N  NaN   N  NaN
# 3  13:25  14:09   Y  C02   N  NaN
# 4  16:10  16:31   N  NaN   N  NaN

# %%
X = df.drop(['SDT_DY','DLY'], axis=1)

# %%
def convert_delay(s):
    if s.DLY == "Y":
        return 1
    else:
        return 0
y = df.apply(convert_delay, axis=1)

# %%
y.head(5)
# Out:
# 0    0
# 1    0
# 2    0
# 3    1
# 4    0
# dtype: int64

# %%
#Label distribution
label_value_count = y.value_counts()
sns.barplot(x=label_value_count.index, y=label_value_count.values)

# %% [markdown]
# ## Training the model

# %%
import seaborn as sns
import math
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
X.dtypes
# Out:
# SDT_YY     int64
# SDT_MM     int64
# SDT_DD     int64
# ARP       object
# ODP       object
# FLO       object
# FLT       object
# REG       object
# AOD       object
# IRR       object
# STT       object
# ATT       object
# DRR       object
# CNL       object
# CNR       object
# dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=0)

# %%
X.dtypes
# Out:
# SDT_YY     int64
# SDT_MM     int64
# SDT_DD     int64
# ARP       object
# ODP       object
# FLO       object
# FLT       object
# REG       object
# AOD       object
# IRR       object
# STT       object
# ATT       object
# DRR       object
# CNL       object
# CNR       object
# dtype: object

# %% [markdown]
# ### label encode the categorical values and convert them to numbers

# %%
X_test.shape
# Out:
# (197542, 15)

# %%
X_train.shape
# Out:
# (790167, 15)

# %%
X.shape
# Out:
# (987709, 15)

# %%
y.shape
# Out:
# (987709,)

# %%
y_train.shape
# Out:
# (790167,)

# %%
X_train.head(5)
# Out:
#         SDT_YY  SDT_MM  SDT_DD   ARP   ODP FLO    FLT       REG AOD IRR  \
# 724366    2018       1      27  ARP3  ARP6   I  I1557  SEw3Nzg2   A   N
# 397753    2018       1       1  ARP1  ARP2   J  J1110  SEw3NzE3   D   N
# 830612    2019       5       6  ARP1  ARP3   J  J1204  SEw3NTk5   D   N
# 341773    2017       6      12  ARP6  ARP3   I  I1582  SEw3NTU2   A   N
# 268787    2017      12       7  ARP8  ARP3   A  A1148  SEw3NzM4   A   N
#
#           STT    ATT  DRR CNL  CNR
# 724366  15:15  15:31  NaN   N  NaN
# 397753  10:00  10:11  NaN   N  NaN
# 830612   6:20   6:34  NaN   N  NaN
# 341773  10:50  11:08  NaN   N  NaN
# 268787  17:50  18:57  C02   N  NaN

# %%
y.head(5)
# Out:
# 0    0
# 1    0
# 2    0
# 3    1
# 4    0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(X_train['ARP'].astype(str))
le.transform(X_train['ARP'].astype(str))

le.fit(X_train['ODP'].astype(str))
le.transform(X_train['ODP'].astype(str))

le.fit(X_train['FLO'].astype(str))
le.transform(X_train['FLO'].astype(str))
# Out:
# array([ 8,  9,  9, ...,  9,  7, 11])

# %% [markdown]
# # A more definitive form

# %%
train_data =pd.read_csv("F:/flight_delay_new/AFSNT.csv",encoding = "ISO-8859-1")

# %%
test_data= pd.read_csv("F:/flight_delay_new/AFSNT_DLY.csv",encoding = "ISO-8859-1")

# %%
train_data.shape
# Out:
# (987709, 17)

# %%
test_data.shape
# Out:
# (16076, 12)

# %%
test_data.head(5)
# Out:
#    SDT_YY  SDT_MM  SDT_DD SDT_DY   ARP   ODP FLO    FLT AOD    STT  DLY  \
# 0    2019       9      16     ¿ù  ARP1  ARP3   L  L1702   A   9:05  NaN
# 1    2019       9      16     ¿ù  ARP3  ARP1   L  L1702   D   7:55  NaN
# 2    2019       9      16     ¿ù     `  ARP3   L  L1720   A  14:40  NaN
# 3    2019       9      16     ¿ù  ARP3  ARP1   L  L1720   D  13:30  NaN
# 4    2019       9      16     ¿ù  ARP4  ARP3   L  L1808   A  20:10  NaN
#
#    DLY_RATE
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
train_data.head(5)
# Out:
#    SDT_YY  SDT_MM  SDT_DD SDT_DY   ARP   ODP FLO    FLT       REG AOD IRR  \
# 0    2017       1       1     ÀÏ  ARP3  ARP6   J  J1955  SEw3NzE4   D   N
# 1    2017       1       1     ÀÏ  ARP3  ARP6   J  J1954  SEw3NzE4   A   N
# 2    2017       1       1     ÀÏ  ARP3  ARP6   J  J1956  SEw3NzE4   A   N
# 3    2017       1       1     ÀÏ  ARP3  ARP6   J  J1957  SEw3NzE4   D   N
# 4    2017       1       1     ÀÏ  ARP3  ARP6   J  J1958  SEw3NzE4   A   N
#
#      STT    ATT DLY CNL  CNR
# 0  10:05  10:32   N   N  NaN
# 1   9:30   9:31   N   N  NaN
# 2  12:45  13:03   N   N  NaN
# 3  13:25  14:09   Y   N  NaN
# 4  16:10  16:31   N   N  NaN

# %%
train_data= train_data.drop(['CNL'], axis=1)

# %%
#label encoding for training data

from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
train_data ["ARP"] = labelencoder.fit_transform(train_data["ARP"])
train_data ["SDT_DY"] = labelencoder.fit_transform(train_data["SDT_DY"])
train_data ["ODP"] = labelencoder.fit_transform(train_data["ODP"])
train_data ["FLO"] = labelencoder.fit_transform(train_data["FLO"])
train_data ["FLT"] = labelencoder.fit_transform(train_data["FLT"])
#train_data ["REG"] = labelencoder.fit_transform(train_data["REG"])
train_data ["AOD"] = labelencoder.fit_transform(train_data["AOD"])
train_data ["IRR"] = labelencoder.fit_transform(train_data["IRR"])
train_data ["DLY"] = labelencoder.fit_transform(train_data["DLY"])

# %%
train_data
# Out:
#         SDT_YY  SDT_MM  SDT_DD  SDT_DY  ARP  ODP  FLO   FLT       REG  AOD  \
# 0         2017       1       1       4    8   11    9  1407  SEw3NzE4    1
# 1         2017       1       1       4    8   11    9  1406  SEw3NzE4    0
# 2         2017       1       1       4    8   11    9  1408  SEw3NzE4    0
# 3         2017       1       1       4    8   11    9  1409  SEw3NzE4    1
# 4         2017       1       1       4    8   11    9  1410  SEw3NzE4    0
# 5         2017       1       1       4    8   11    9  1411  SEw3NTk5    1
# 6         2017       1       1       4    8   11    9  1412  SEw3NTk5    0
# 7         2017       1       1       4    8   11    9  1413  SEw3NTk5    1
# 8         2017       1       1       4    7    8    9  1061  SEw3NzA2    0
# 9         2017       1       1       4    0    8    9  1209  SEw3NzA2    1
# 10        2017       1       1       4    0    8    9  1224  SEw3NzA4    0
# 11        2017       1       1       4    0    8    9  1187  SEw3NzA4    1
# 12        2017       1       1       4    0    8    9  1170  SEw3NzA4    0
# 13        2017       1       1       4    9    8    9  1371  SEw3NzA4    0
# 14        2017       1       1       4    9    8    9  1372  SEw3NzA4    1
# 15        2017       1       1       4    0    8    9  1221  SEw3NzA4    1
# 16        2017       1       1       4    7    8    9  1067  SEw3NzA4    0
# 17        2017       1       1       4    0    8    9  1202  SEw3NzE2    0
# 18        2017       1       1       4    0    8    9  1225  SEw3NTY2    1
# 19        2017       1       1       4    0    8    9  1203  SEw3NzE2    1
# 20        2017       1       1       4    0    8    9  1215  SEw3NzE2    1
# 21        2017       1       1       4   13    8    9  1396  SEw3NzE2    0
# 22        2017       1       1       4   13    8    9  1395  SEw3NzE2    1
# 23        2017       1       1       4    9    8    9  1365  SEw4MjQx    1
# 24        2017       1       1       4    5    8    9  1378  SEw4MjQx    0
# 25        2017       1       1       4    5    8    9  1377  SEw4MjQx    1
# 26        2017       1       1       4    3    8    9  1376  SEw4MjQx    0
# 27        2017       1       1       4    0    8    9  1186  SEw3NTY2    0
# 28        2017       1       1       4    0    8    9  1220  SEw3NzE2    0
# 29        2017       1       1       4    3    8    9  1375  SEw4MjQx    1
# ...        ...     ...     ...     ...  ...  ...  ...   ...       ...  ...
# 987679    2019       6      30       4    8    0   11  1483  SEw4MzIz    1
# 987680    2019       6      30       4    8    0   11  1467  SEw4MzIz    1
# 987681    2019       6      30       4    8    0   11  1460  SEw4MzIz    0
# 987682    2019       6      30       4    8    0   11  1452  SEw4MzIz    0
# 987683    2019       6      30       4    8    0   11  1455  SEw4MzIz    1
# 987684    2019       6      30       4    8    0   11  1475  SEw4MzIz    1
# 987685    2019       6      30       4    8    0   11  1482  SEw4MzIz    0
# 987686    2019       6      30       4    8    0   11  1472  SEw4MzIz    0
# 987687    2019       6      30       4    8    0   11  1448  SEw4MzU0    0
# 987688    2019       6      30       4    8    0   11  1450  SEw4MzU0    0
# 987689    2019       6      30       4    8    0   11  1449  SEw4MzU0    1
# 987690    2019       6      30       4    8    0   11  1451  SEw4MjM3    1
# 987691    2019       6      30       4    8   13   11  1530  SEw4MDk4    0
# 987692    2019       6      30       4    8   13   11  1531  SEw4MDk4    1
# 987693    2019       6      30       4    8   13   11  1533  SEw4MDAw    1
# 987694    2019       6      30       4    8   13   11  1532  SEw4MDAw    0
# 987695    2019       6      30       4    8   13   11  1535  SEw4MDAw    1
# 987696    2019       6      30       4    8   13   11  1534  SEw4MDAw    0
# 987697    2019       6      30       4    8   12   11  1539  SEw4MDk4    0
# 987698    2019       6      30       4    8   12   11  1540  SEw4MzU0    1
# 987699    2019       6      30       4    8    9   11  1513  SEw4MDU2    0
# 987700    2019       6      30       4    8    9   11  1510  SEw4MDU2    1
# 987701    2019       6      30       4    8    9   11  1514  SEw4MDAw    1
# 987702    2019       6      30       4    8    9   11  1511  SEw4MDAw    0
# 987703    2019       6      30       4    8    9   11  1516  SEw4MzYz    1
# 987704    2019       6      30       4    8    9   11  1518  SEw4MjM1    1
# 987705    2019       6      30       4    8    9   11  1517  SEw4MjM1    0
# 987706    2019       6      30       4    8    9   11  1509  SEw4MzYz    0
# 987707    2019       6      30       4    8    9   11  1515  SEw4MjM3    0
# 987708    2019       6      30       4    8    9   11  1512  SEw4MjM3    1
#
#         IRR    STT    ATT  DLY  CNR
# 0         0  10:05  10:32    0  NaN
# 1         0   9:30   9:31    0  NaN
# 2         0  12:45  13:03    0  NaN
# 3         0  13:25  14:09    1  NaN
# 4         0  16:10  16:31    0  NaN
# 5         0  16:45  17:21    1  NaN
# 6         0  19:30  19:43    0  NaN
# 7         0  20:35  20:52    0  NaN
# 8         0  17:05  17:03    0  NaN
# 9         0  20:25  20:36    0  NaN
# 10        0  12:40  12:44    0  NaN
# 11        0  13:25  13:41    0  NaN
# 12        0   8:05   8:03    0  NaN
# 13        0  17:45  17:36    0  NaN
# 14        0  18:25  18:35    0  NaN
# 15        0   9:05   9:24    0  NaN
# 16        0  21:05  20:59    0  NaN
# 17        0  18:55  19:29    1  NaN
# 18        0  11:30  11:43    0  NaN
# 19        0  13:15  13:25    0  NaN
# 20        0  21:00  21:16    0  NaN
# 21        0  15:45  15:55    0  NaN
# 22        0  16:20  16:53    1  NaN
# 23        0   9:30   9:50    0  NaN
# 24        0  12:15  12:14    0  NaN
# 25        0  13:10  13:20    0  NaN
# 26        0  16:15  16:13    0  NaN
# 27        0  14:25  14:33    0  NaN
# 28        0   8:15   8:14    0  NaN
# 29        0  17:10  17:18    0  NaN
# ...     ...    ...    ...  ...  ...
# 987679    0  21:05  21:19    0  NaN
# 987680    0  13:30  13:43    0  NaN
# 987681    0  12:55  12:48    0  NaN
# 987682    0   9:25   9:13    0  NaN
# 987683    0  10:00  10:15    0  NaN
# 987684    0  17:05  17:36    1  NaN
# 987685    0  20:00  20:27    0  NaN
# 987686    0  16:25  16:38    0  NaN
# 987687    1  12:00  11:51    0  NaN
# 987688    1  17:10  17:23    0  NaN
# 987689    1  12:35  12:47    0  NaN
# 987690    1  18:00  18:36    1  NaN
# 987691    0  10:25  10:08    0  NaN
# 987692    0   8:05   8:15    0  NaN
# 987693    0  10:50  11:08    0  NaN
# 987694    0  12:55  12:57    0  NaN
# 987695    0  13:25  13:49    0  NaN
# 987696    0  15:30  15:39    0  NaN
# 987697    0   7:30   7:16    0  NaN
# 987698    0  18:10  18:33    0  NaN
# 987699    0  11:05  10:49    0  NaN
# 987700    0   8:25   8:35    0  NaN
# 987701    0  18:05  18:35    0  NaN
# 987702    0   9:55   9:49    0  NaN
# 987703    0  19:10  19:24    0  NaN
# 987704    0  21:10  21:53    1  NaN
# 987705    0  20:35  20:59    0  NaN
# 987706    0   7:20   7:10    0  NaN
# 987707    0  17:30  17:32    0  NaN
# 987708    0  14:45  14:54    0  NaN
#
# [987709 rows x 15 columns]

# %%
test_data.head(5)
# Out:
#    SDT_YY  SDT_MM  SDT_DD  SDT_DY  ARP  ODP  FLO  FLT  AOD  \
# 0    2019       9      16       3    0    8    6  544    0
# 1    2019       9      16       3    8    0    6  544    1
# 2    2019       9      16       3   15    8    6  562    0
# 3    2019       9      16       3    8    0    6  562    1
# 4    2019       9      16       3    9    8    6  586    0
#
#                   STT  DLY  DLY_RATE
# 0 2019-08-05 10:05:00  NaN       NaN
# 1 2019-08-05 09:30:00  NaN       NaN
# 2 2019-08-05 12:45:00  NaN       NaN
# 3 2019-08-05 13:25:00  NaN       NaN
# 4 2019-08-05 16:10:00  NaN       NaN

# %%
test_data.columns
# Out:
# Index(['SDT_YY', 'SDT_MM', 'SDT_DD', 'SDT_DY', 'ARP', 'ODP', 'FLO', 'FLT',
#        'AOD', 'STT', 'DLY', 'DLY_RATE'],
#       dtype='object')

# %%
#test_data= train_data.drop(['SDT_DY'], axis=1)

# %%
#label encoding for test_data

from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
test_data ["ARP"] = labelencoder.fit_transform(test_data["ARP"])
test_data ["SDT_DY"] = labelencoder.fit_transform(test_data["SDT_DY"])
test_data ["ODP"] = labelencoder.fit_transform(test_data["ODP"])
test_data ["FLO"] = labelencoder.fit_transform(test_data["FLO"])
test_data ["FLT"] = labelencoder.fit_transform(test_data["FLT"])
#train_data ["REG"] = labelencoder.fit_transform(train_data["REG"])
test_data ["AOD"] = labelencoder.fit_transform(test_data["AOD"])
#test_data ["DLY"] = labelencoder.fit_transform(train_data["DLY"])

# %%
train_data['STT'] = pd.to_datetime(train_data['STT'] )
train_data['ATT'] = pd.to_datetime(train_data['ATT'])

test_data['STT'] = pd.to_datetime(train_data['STT'])

# %%
train_data.dtypes
# Out:
# SDT_YY             int64
# SDT_MM             int64
# SDT_DD             int64
# SDT_DY             int64
# ARP                int64
# ODP                int64
# FLO                int64
# FLT                int64
# REG               object
# AOD                int64
# IRR                int64
# STT       datetime64[ns]
# ATT       datetime64[ns]
# DLY                int64
# CNR               object
# dtype: object

# %%
def time_delay(s):
    s_hour = s['STT'].hour
    s_min = s['STT'].minute
    a_hour = s['ATT'].hour
    a_min = s['ATT'].minute
    
    time_dif = (a_hour - s_hour) * 60 + a_min - s_min
    return time_dif

train_data['TIME_DIF'] = train_data.apply(time_delay, axis=1)

# %%
train_data.head()
# Out:
#    SDT_YY  SDT_MM  SDT_DD  SDT_DY  ARP  ODP  FLO   FLT       REG  AOD  IRR  \
# 0    2017       1       1       4    8   11    9  1407  SEw3NzE4    1    0
# 1    2017       1       1       4    8   11    9  1406  SEw3NzE4    0    0
# 2    2017       1       1       4    8   11    9  1408  SEw3NzE4    0    0
# 3    2017       1       1       4    8   11    9  1409  SEw3NzE4    1    0
# 4    2017       1       1       4    8   11    9  1410  SEw3NzE4    0    0
#
#                   STT                 ATT  DLY  CNR  TIME_DIF
# 0 2019-08-05 10:05:00 2019-08-05 10:32:00    0  NaN        27
# 1 2019-08-05 09:30:00 2019-08-05 09:31:00    0  NaN         1
# 2 2019-08-05 12:45:00 2019-08-05 13:03:00    0  NaN        18
# 3 2019-08-05 13:25:00 2019-08-05 14:09:00    1  NaN        44
# 4 2019-08-05 16:10:00 2019-08-05 16:31:00    0  NaN        21

# %%
#train_data.CNR.fillna()

# %%
train_data.CNR.value_counts()
# Out:
# 0    987709
# Name: CNR, dtype: int64

# %%
train_data
# Out:
#         SDT_YY  SDT_MM  SDT_DD  SDT_DY  ARP  ODP  FLO   FLT       REG  AOD  \
# 0         2017       1       1       4    8   11    9  1407  SEw3NzE4    1
# 1         2017       1       1       4    8   11    9  1406  SEw3NzE4    0
# 2         2017       1       1       4    8   11    9  1408  SEw3NzE4    0
# 3         2017       1       1       4    8   11    9  1409  SEw3NzE4    1
# 4         2017       1       1       4    8   11    9  1410  SEw3NzE4    0
# 5         2017       1       1       4    8   11    9  1411  SEw3NTk5    1
# 6         2017       1       1       4    8   11    9  1412  SEw3NTk5    0
# 7         2017       1       1       4    8   11    9  1413  SEw3NTk5    1
# 8         2017       1       1       4    7    8    9  1061  SEw3NzA2    0
# 9         2017       1       1       4    0    8    9  1209  SEw3NzA2    1
# 10        2017       1       1       4    0    8    9  1224  SEw3NzA4    0
# 11        2017       1       1       4    0    8    9  1187  SEw3NzA4    1
# 12        2017       1       1       4    0    8    9  1170  SEw3NzA4    0
# 13        2017       1       1       4    9    8    9  1371  SEw3NzA4    0
# 14        2017       1       1       4    9    8    9  1372  SEw3NzA4    1
# 15        2017       1       1       4    0    8    9  1221  SEw3NzA4    1
# 16        2017       1       1       4    7    8    9  1067  SEw3NzA4    0
# 17        2017       1       1       4    0    8    9  1202  SEw3NzE2    0
# 18        2017       1       1       4    0    8    9  1225  SEw3NTY2    1
# 19        2017       1       1       4    0    8    9  1203  SEw3NzE2    1
# 20        2017       1       1       4    0    8    9  1215  SEw3NzE2    1
# 21        2017       1       1       4   13    8    9  1396  SEw3NzE2    0
# 22        2017       1       1       4   13    8    9  1395  SEw3NzE2    1
# 23        2017       1       1       4    9    8    9  1365  SEw4MjQx    1
# 24        2017       1       1       4    5    8    9  1378  SEw4MjQx    0
# 25        2017       1       1       4    5    8    9  1377  SEw4MjQx    1
# 26        2017       1       1       4    3    8    9  1376  SEw4MjQx    0
# 27        2017       1       1       4    0    8    9  1186  SEw3NTY2    0
# 28        2017       1       1       4    0    8    9  1220  SEw3NzE2    0
# 29        2017       1       1       4    3    8    9  1375  SEw4MjQx    1
# ...        ...     ...     ...     ...  ...  ...  ...   ...       ...  ...
# 987679    2019       6      30       4    8    0   11  1483  SEw4MzIz    1
# 987680    2019       6      30       4    8    0   11  1467  SEw4MzIz    1
# 987681    2019       6      30       4    8    0   11  1460  SEw4MzIz    0
# 987682    2019       6      30       4    8    0   11  1452  SEw4MzIz    0
# 987683    2019       6      30       4    8    0   11  1455  SEw4MzIz    1
# 987684    2019       6      30       4    8    0   11  1475  SEw4MzIz    1
# 987685    2019       6      30       4    8    0   11  1482  SEw4MzIz    0
# 987686    2019       6      30       4    8    0   11  1472  SEw4MzIz    0
# 987687    2019       6      30       4    8    0   11  1448  SEw4MzU0    0
# 987688    2019       6      30       4    8    0   11  1450  SEw4MzU0    0
# 987689    2019       6      30       4    8    0   11  1449  SEw4MzU0    1
# 987690    2019       6      30       4    8    0   11  1451  SEw4MjM3    1
# 987691    2019       6      30       4    8   13   11  1530  SEw4MDk4    0
# 987692    2019       6      30       4    8   13   11  1531  SEw4MDk4    1
# 987693    2019       6      30       4    8   13   11  1533  SEw4MDAw    1
# 987694    2019       6      30       4    8   13   11  1532  SEw4MDAw    0
# 987695    2019       6      30       4    8   13   11  1535  SEw4MDAw    1
# 987696    2019       6      30       4    8   13   11  1534  SEw4MDAw    0
# 987697    2019       6      30       4    8   12   11  1539  SEw4MDk4    0
# 987698    2019       6      30       4    8   12   11  1540  SEw4MzU0    1
# 987699    2019       6      30       4    8    9   11  1513  SEw4MDU2    0
# 987700    2019       6      30       4    8    9   11  1510  SEw4MDU2    1
# 987701    2019       6      30       4    8    9   11  1514  SEw4MDAw    1
# 987702    2019       6      30       4    8    9   11  1511  SEw4MDAw    0
# 987703    2019       6      30       4    8    9   11  1516  SEw4MzYz    1
# 987704    2019       6      30       4    8    9   11  1518  SEw4MjM1    1
# 987705    2019       6      30       4    8    9   11  1517  SEw4MjM1    0
# 987706    2019       6      30       4    8    9   11  1509  SEw4MzYz    0
# 987707    2019       6      30       4    8    9   11  1515  SEw4MjM3    0
# 987708    2019       6      30       4    8    9   11  1512  SEw4MjM3    1
#
#         IRR                 STT                 ATT  DLY  CNR  TIME_DIF
# 0         0 2019-08-05 10:05:00 2019-08-05 10:32:00    0    0        27
# 1         0 2019-08-05 09:30:00 2019-08-05 09:31:00    0    0         1
# 2         0 2019-08-05 12:45:00 2019-08-05 13:03:00    0    0        18
# 3         0 2019-08-05 13:25:00 2019-08-05 14:09:00    1    0        44
# 4         0 2019-08-05 16:10:00 2019-08-05 16:31:00    0    0        21
# 5         0 2019-08-05 16:45:00 2019-08-05 17:21:00    1    0        36
# 6         0 2019-08-05 19:30:00 2019-08-05 19:43:00    0    0        13
# 7         0 2019-08-05 20:35:00 2019-08-05 20:52:00    0    0        17
# 8         0 2019-08-05 17:05:00 2019-08-05 17:03:00    0    0        -2
# 9         0 2019-08-05 20:25:00 2019-08-05 20:36:00    0    0        11
# 10        0 2019-08-05 12:40:00 2019-08-05 12:44:00    0    0         4
# 11        0 2019-08-05 13:25:00 2019-08-05 13:41:00    0    0        16
# 12        0 2019-08-05 08:05:00 2019-08-05 08:03:00    0    0        -2
# 13        0 2019-08-05 17:45:00 2019-08-05 17:36:00    0    0        -9
# 14        0 2019-08-05 18:25:00 2019-08-05 18:35:00    0    0        10
# 15        0 2019-08-05 09:05:00 2019-08-05 09:24:00    0    0        19
# 16        0 2019-08-05 21:05:00 2019-08-05 20:59:00    0    0        -6
# 17        0 2019-08-05 18:55:00 2019-08-05 19:29:00    1    0        34
# 18        0 2019-08-05 11:30:00 2019-08-05 11:43:00    0    0        13
# 19        0 2019-08-05 13:15:00 2019-08-05 13:25:00    0    0        10
# 20        0 2019-08-05 21:00:00 2019-08-05 21:16:00    0    0        16
# 21        0 2019-08-05 15:45:00 2019-08-05 15:55:00    0    0        10
# 22        0 2019-08-05 16:20:00 2019-08-05 16:53:00    1    0        33
# 23        0 2019-08-05 09:30:00 2019-08-05 09:50:00    0    0        20
# 24        0 2019-08-05 12:15:00 2019-08-05 12:14:00    0    0        -1
# 25        0 2019-08-05 13:10:00 2019-08-05 13:20:00    0    0        10
# 26        0 2019-08-05 16:15:00 2019-08-05 16:13:00    0    0        -2
# 27        0 2019-08-05 14:25:00 2019-08-05 14:33:00    0    0         8
# 28        0 2019-08-05 08:15:00 2019-08-05 08:14:00    0    0        -1
# 29        0 2019-08-05 17:10:00 2019-08-05 17:18:00    0    0         8
# ...     ...                 ...                 ...  ...  ...       ...
# 987679    0 2019-08-05 21:05:00 2019-08-05 21:19:00    0    0        14
# 987680    0 2019-08-05 13:30:00 2019-08-05 13:43:00    0    0        13
# 987681    0 2019-08-05 12:55:00 2019-08-05 12:48:00    0    0        -7
# 987682    0 2019-08-05 09:25:00 2019-08-05 09:13:00    0    0       -12
# 987683    0 2019-08-05 10:00:00 2019-08-05 10:15:00    0    0        15
# 987684    0 2019-08-05 17:05:00 2019-08-05 17:36:00    1    0        31
# 987685    0 2019-08-05 20:00:00 2019-08-05 20:27:00    0    0        27
# 987686    0 2019-08-05 16:25:00 2019-08-05 16:38:00    0    0        13
# 987687    1 2019-08-05 12:00:00 2019-08-05 11:51:00    0    0        -9
# 987688    1 2019-08-05 17:10:00 2019-08-05 17:23:00    0    0        13
# 987689    1 2019-08-05 12:35:00 2019-08-05 12:47:00    0    0        12
# 987690    1 2019-08-05 18:00:00 2019-08-05 18:36:00    1    0        36
# 987691    0 2019-08-05 10:25:00 2019-08-05 10:08:00    0    0       -17
# 987692    0 2019-08-05 08:05:00 2019-08-05 08:15:00    0    0        10
# 987693    0 2019-08-05 10:50:00 2019-08-05 11:08:00    0    0        18
# 987694    0 2019-08-05 12:55:00 2019-08-05 12:57:00    0    0         2
# 987695    0 2019-08-05 13:25:00 2019-08-05 13:49:00    0    0        24
# 987696    0 2019-08-05 15:30:00 2019-08-05 15:39:00    0    0         9
# 987697    0 2019-08-05 07:30:00 2019-08-05 07:16:00    0    0       -14
# 987698    0 2019-08-05 18:10:00 2019-08-05 18:33:00    0    0        23
# 987699    0 2019-08-05 11:05:00 2019-08-05 10:49:00    0    0       -16
# 987700    0 2019-08-05 08:25:00 2019-08-05 08:35:00    0    0        10
# 987701    0 2019-08-05 18:05:00 2019-08-05 18:35:00    0    0        30
# 987702    0 2019-08-05 09:55:00 2019-08-05 09:49:00    0    0        -6
# 987703    0 2019-08-05 19:10:00 2019-08-05 19:24:00    0    0        14
# 987704    0 2019-08-05 21:10:00 2019-08-05 21:53:00    1    0        43
# 987705    0 2019-08-05 20:35:00 2019-08-05 20:59:00    0    0        24
# 987706    0 2019-08-05 07:20:00 2019-08-05 07:10:00    0    0       -10
# 987707    0 2019-08-05 17:30:00 2019-08-05 17:32:00    0    0         2
# 987708    0 2019-08-05 14:45:00 2019-08-05 14:54:00    0    0         9
#
# [987709 rows x 16 columns]

# %%
train_data.isnull().sum()
# Out:
# SDT_YY         0
# SDT_MM         0
# SDT_DD         0
# SDT_DY         0
# ARP            0
# ODP            0
# FLO            0
# FLT            0
# REG         8263
# AOD            0
# IRR            0
# STT            0
# ATT            0
# DLY            0
# CNR            0
# TIME_DIF       0
# dtype: int64

# %%
X.isnull().sum()
# Out:
# SDT_YY      0
# SDT_MM      0
# SDT_DD      0
# SDT_DY      0
# ARP         0
# ODP         0
# FLO         0
# FLT         0
# AOD         0
# IRR         0
# DLY         0
# CNR         0
# TIME_DIF    0
# dtype: int64

# %%
y.isnull().sum()
# Out:
# SDT_YY          0
# SDT_MM          0
# SDT_DD          0
# SDT_DY          0
# ARP             0
# ODP             0
# FLO             0
# FLT             0
# AOD             0
# STT             0
# DLY         16076
# DLY_RATE    16076
# dtype: int64

# %% [markdown]
# ## CLASSIFIER

# %%
X= train_data.drop(['REG','STT','ATT','DLY','TIME_DIF'], axis=1)
y=train_data['DLY']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=0)

# %%
clf = RandomForestClassifier(n_jobs=4, random_state=0)
clf.fit(X, y)
# Out:
# C:\Users\Timothy\Anaconda2\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=4,
#                        oob_score=False, random_state=0, verbose=0,
#                        warm_start=False)

# %%
y_pred = clf.predict(X_test)
print("Baseline accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Baseline accuracy: 0.9851170753258228

# %%
feature_list = train_data.columns
importances = list(clf.feature_importances_)
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(feature_list, importances)]
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)
[print('Variable: {:40} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# Variable: FLT                                      Importance: 0.41
# Variable: SDT_DD                                   Importance: 0.26
# Variable: SDT_MM                                   Importance: 0.13
# Variable: SDT_DY                                   Importance: 0.08
# Variable: SDT_YY                                   Importance: 0.03
# Variable: REG                                      Importance: 0.03
# Variable: ARP                                      Importance: 0.02
# Variable: ODP                                      Importance: 0.02
# Variable: FLO                                      Importance: 0.01
# Variable: AOD                                      Importance: 0.0
# Variable: IRR                                      Importance: 0.0

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# overall accuracy
acc = clf.score(X_test,y_test)

# get roc/auc info
Y_score = clf.predict_proba(X_test)[:,1]
fpr = dict()
tpr = dict()
fpr, tpr, _ = roc_curve(y_test, Y_score)

roc_auc = dict()
roc_auc = auc(fpr, tpr)

# make the plot
plt.figure(figsize=(10,10))
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([-0.05, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.grid(True)
plt.plot(fpr, tpr, label='AUC = {0}'.format(roc_auc))        
plt.legend(loc="lower right", shadow=True, fancybox =True) 
plt.show()
